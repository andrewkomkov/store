# %%
import requests
from bs4 import BeautifulSoup

# Загрузка страницы
url = 'http://auto.tgvpn.tk/?target=map'
response = requests.get(url)

print (response)
# Out:
# <Response [200]>

# %%
# Проверка успешности запроса
if response.status_code == 200:
    # Извлечение HTML-кода страницы
    html = response.text
    
    # Создание объекта BeautifulSoup для парсинга HTML
    soup = BeautifulSoup(html, 'html.parser')
    
    # Нахождение всех элементов <a> на странице
    links = soup.find_all('a')
    
    # Обход каждой найденной ссылки
    for link in links:
        # Получение URL ссылки
        href = link.get('href')
        try:
            requests.get(href)
        except:
            pass
        print(href)  # Вывод URL ссылки или можно выполнить другие действия
else:
    print('Ошибка при загрузке страницы:', response.status_code)
# Out:
# http://auto.tgvpn.tk/interior-accessories/
# http://auto.tgvpn.tk/interior-accessories/wheels-and-shift-knobs/
# http://auto.tgvpn.tk/interior-accessories/seat-covers/
# http://auto.tgvpn.tk/interior-accessories/custom-gauges/
# http://auto.tgvpn.tk/exterior-accessories/
# http://auto.tgvpn.tk/exterior-accessories/bumpers/
# http://auto.tgvpn.tk/exterior-accessories/halo-headlights/
# http://auto.tgvpn.tk/exterior-accessories/mirrors/
# http://auto.tgvpn.tk/exterior-accessories/grille-guards/
# http://auto.tgvpn.tk/performance/
# http://auto.tgvpn.tk/performance/steering-wheels/
# http://auto.tgvpn.tk/performance/transmission/
# http://auto.tgvpn.tk/performance/turbos-and-superchargers/
# http://auto.tgvpn.tk/performance/air-intake-and-fuel-delivery/
# http://auto.tgvpn.tk/lighting/
# http://auto.tgvpn.tk/lighting/headlights/
# http://auto.tgvpn.tk/lighting/car-bulbs/
# http://auto.tgvpn.tk/lighting/tail-lights/
# http://auto.tgvpn.tk/accessories/
# http://auto.tgvpn.tk/accessories/radar-detectors/
# http://auto.tgvpn.tk/accessories/gps-navigation-systems/
# http://auto.tgvpn.tk/accessories/cameras-and-driver-safety/
# http://auto.tgvpn.tk/repair-parts/
# http://auto.tgvpn.tk/repair-parts/big-brake-kits/
# http://auto.tgvpn.tk/repair-parts/Braided-brake-lines/
# http://auto.tgvpn.tk/repair-parts/brake-calipers/
# http://auto.tgvpn.tk/cooling-systems/
# http://auto.tgvpn.tk/cooling-systems/antifreeze-and-additives/
# http://auto.tgvpn.tk/cooling-systems/engine-pulleys/
# http://auto.tgvpn.tk/cooling-systems/intercoolers/
# http://auto.tgvpn.tk/wheels-tires-and-parts/
# http://auto.tgvpn.tk/wheels-tires-and-parts/wheel-covers/
# http://auto.tgvpn.tk/wheels-tires-and-parts/wheels/
# http://auto.tgvpn.tk/wheels-tires-and-parts/tires/
# interior-accessories/
# interior-accessories/wheels-and-shift-knobs/
# interior-accessories/seat-covers/
# interior-accessories/custom-gauges/
# exterior-accessories/
# exterior-accessories/bumpers/
# exterior-accessories/halo-headlights/
# exterior-accessories/mirrors/
# exterior-accessories/grille-guards/
# performance/
# performance/steering-wheels/
# performance/transmission/
# performance/turbos-and-superchargers/
# performance/air-intake-and-fuel-delivery/
# lighting/
# lighting/headlights/
# lighting/car-bulbs/
# lighting/tail-lights/
# accessories/
# accessories/radar-detectors/
# accessories/gps-navigation-systems/
# accessories/cameras-and-driver-safety/
# repair-parts/
# repair-parts/big-brake-kits/
# repair-parts/Braided-brake-lines/
# repair-parts/brake-calipers/
# cooling-systems/
# cooling-systems/antifreeze-and-additives/
# cooling-systems/engine-pulleys/
# cooling-systems/intercoolers/
# wheels-tires-and-parts/
# wheels-tires-and-parts/wheel-covers/
# wheels-tires-and-parts/wheels/
# wheels-tires-and-parts/tires/
# http://auto.tgvpn.tk/sale-products/
# http://auto.tgvpn.tk/bestsellers/
# http://auto.tgvpn.tk/newarrivals/
# http://auto.tgvpn.tk/coming-soon/
# shipping
# http://auto.tgvpn.tk/contact-us/
# None
# http://auto.tgvpn.tk/?target=wishlist
# #
# http://auto.tgvpn.tk/
# interior-accessories/
# interior-accessories/wheels-and-shift-knobs/
# interior-accessories/seat-covers/
# interior-accessories/custom-gauges/
# exterior-accessories/
# exterior-accessories/bumpers/
# exterior-accessories/halo-headlights/
# exterior-accessories/mirrors/
# exterior-accessories/grille-guards/
# performance/
# performance/steering-wheels/
# performance/transmission/
# performance/turbos-and-superchargers/
# performance/air-intake-and-fuel-delivery/
# lighting/
# lighting/headlights/
# lighting/car-bulbs/
# lighting/tail-lights/
# accessories/
# accessories/radar-detectors/
# accessories/gps-navigation-systems/
# accessories/cameras-and-driver-safety/
# repair-parts/
# repair-parts/big-brake-kits/
# repair-parts/Braided-brake-lines/
# repair-parts/brake-calipers/
# cooling-systems/
# cooling-systems/antifreeze-and-additives/
# cooling-systems/engine-pulleys/
# cooling-systems/intercoolers/
# wheels-tires-and-parts/
# wheels-tires-and-parts/wheel-covers/
# wheels-tires-and-parts/wheels/
# wheels-tires-and-parts/tires/
# http://auto.tgvpn.tk/sale-products/
# http://auto.tgvpn.tk/bestsellers/
# http://auto.tgvpn.tk/newarrivals/
# http://auto.tgvpn.tk/coming-soon/
# shipping
# http://auto.tgvpn.tk/contact-us/
# None
# None
# None
# http://auto.tgvpn.tk/?target=wishlist
# None
# None
# http://auto.tgvpn.tk/?target=wishlist
# http://auto.tgvpn.tk/?target=cart
# http://auto.tgvpn.tk/?target=cart
# http://auto.tgvpn.tk/?target=checkout
# http://auto.tgvpn.tk/
# None
# None
# #slidebar
# None
# http://auto.tgvpn.tk/interior-accessories/
# http://auto.tgvpn.tk/interior-accessories/wheels-and-shift-knobs/
# http://auto.tgvpn.tk/interior-accessories/seat-covers/
# http://auto.tgvpn.tk/interior-accessories/custom-gauges/
# http://auto.tgvpn.tk/exterior-accessories/
# http://auto.tgvpn.tk/exterior-accessories/bumpers/
# http://auto.tgvpn.tk/exterior-accessories/halo-headlights/
# http://auto.tgvpn.tk/exterior-accessories/mirrors/
# http://auto.tgvpn.tk/exterior-accessories/grille-guards/
# http://auto.tgvpn.tk/performance/
# http://auto.tgvpn.tk/performance/steering-wheels/
# http://auto.tgvpn.tk/performance/transmission/
# http://auto.tgvpn.tk/performance/turbos-and-superchargers/
# http://auto.tgvpn.tk/performance/air-intake-and-fuel-delivery/
# http://auto.tgvpn.tk/lighting/
# http://auto.tgvpn.tk/lighting/headlights/
# http://auto.tgvpn.tk/lighting/car-bulbs/
# http://auto.tgvpn.tk/lighting/tail-lights/
# http://auto.tgvpn.tk/accessories/
# http://auto.tgvpn.tk/accessories/radar-detectors/
# http://auto.tgvpn.tk/accessories/gps-navigation-systems/
# http://auto.tgvpn.tk/accessories/cameras-and-driver-safety/
# http://auto.tgvpn.tk/repair-parts/
# http://auto.tgvpn.tk/repair-parts/big-brake-kits/
# http://auto.tgvpn.tk/repair-parts/Braided-brake-lines/
# http://auto.tgvpn.tk/repair-parts/brake-calipers/
# http://auto.tgvpn.tk/cooling-systems/
# http://auto.tgvpn.tk/cooling-systems/antifreeze-and-additives/
# http://auto.tgvpn.tk/cooling-systems/engine-pulleys/
# http://auto.tgvpn.tk/cooling-systems/intercoolers/
# http://auto.tgvpn.tk/wheels-tires-and-parts/
# http://auto.tgvpn.tk/wheels-tires-and-parts/wheel-covers/
# http://auto.tgvpn.tk/wheels-tires-and-parts/wheels/
# http://auto.tgvpn.tk/wheels-tires-and-parts/tires/
# http://auto.tgvpn.tk/sale-products/
# http://auto.tgvpn.tk/newarrivals/
# http://auto.tgvpn.tk/coming-soon/
# http://auto.tgvpn.tk/?target=cart
# http://auto.tgvpn.tk/?target=checkout
# http://auto.tgvpn.tk/?target=login
# http://auto.tgvpn.tk/?target=profile&mode=register
# http://auto.tgvpn.tk/shipping
# http://auto.tgvpn.tk/terms-and-conditions
# http://auto.tgvpn.tk/?target=contact_us
# mailto:admin@example.com
# http://auto.tgvpn.tk/sale-products/
# http://auto.tgvpn.tk/coming-soon/
# http://auto.tgvpn.tk/newarrivals/
# shipping
# ?target=map
# terms-and-conditions
# shipping
# http://auto.tgvpn.tk/contact-us/
